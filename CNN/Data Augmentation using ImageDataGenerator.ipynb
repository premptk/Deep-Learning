# %%
#Data Augmentation using Keras and ImageDataGenerator
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

datagen = ImageDataGenerator(
            rotation_range=40,  #rotation_range is a value in degrees (0-180), a range within which to randomly rotate pictures
            width_shift_range=0.2,   #shifting range
            height_shift_range=0.2,
            shear_range=0.2,  #randomly applying shearing transformation
            zoom_range=0.2,  #zooming image
            horizontal_flip=True,
            fill_mode='nearest')  #fill_mode is the strategy used for filling in newly created pixels

# %%
img = load_img('C:\PREM\MACHINE LEARNING\Deep Learning\CNN\cat.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=236x240 at 0x23F17F2DE20>

# %%
X = img_to_array(img) ## this is a Numpy array with shape (3, 150, 150)
X = X.reshape((1,) + X.shape)  # this is a Numpy array with shape (1, 3, 150, 150)
X.shape
# Out:
# (1, 240, 236, 3)

# %%
i = 0
for batch in datagen.flow(X, batch_size=1, 
                         save_to_dir='C:\PREM\MACHINE LEARNING\Deep Learning\CNN\preview', save_prefix='cat', save_format='jpg'):
    i+=1
    if i>20:
        break

# %%
import glob
from IPython.display import Image, display
for imageName in glob.glob('C:\PREM\MACHINE LEARNING\Deep Learning\CNN\preview\*.JPG'): #assuming JPG
    display(Image(filename=imageName))
    print(imageName)
# Out:
# C:\PREM\MACHINE LEARNING\Deep Learning\CNN\preview\cat_0_1448.jpg
# C:\PREM\MACHINE LEARNING\Deep Learning\CNN\preview\cat_0_1527.jpg
# C:\PREM\MACHINE LEARNING\Deep Learning\CNN\preview\cat_0_1777.jpg
# C:\PREM\MACHINE LEARNING\Deep Learning\CNN\preview\cat_0_1851.jpg
# C:\PREM\MACHINE LEARNING\Deep Learning\CNN\preview\cat_0_1874.jpg
# C:\PREM\MACHINE LEARNING\Deep Learning\CNN\preview\cat_0_2093.jpg
# C:\PREM\MACHINE LEARNING\Deep Learning\CNN\preview\cat_0_2351.jpg
# C:\PREM\MACHINE LEARNING\Deep Learning\CNN\preview\cat_0_2495.jpg
# C:\PREM\MACHINE LEARNING\Deep Learning\CNN\preview\cat_0_2813.jpg
# C:\PREM\MACHINE LEARNING\Deep Learning\CNN\preview\cat_0_2996.jpg
# C:\PREM\MACHINE LEARNING\Deep Learning\CNN\preview\cat_0_3918.jpg
# C:\PREM\MACHINE LEARNING\Deep Learning\CNN\preview\cat_0_3977.jpg
# C:\PREM\MACHINE LEARNING\Deep Learning\CNN\preview\cat_0_4349.jpg
# C:\PREM\MACHINE LEARNING\Deep Learning\CNN\preview\cat_0_436.jpg
# ...
